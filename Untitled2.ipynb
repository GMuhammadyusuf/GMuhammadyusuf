# %% [markdown]
# <a href="https://colab.research.google.com/github/GMuhammadyusuf/GMuhammadyusuf/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Workshop 02 - Predicting loan case using Decision Tree**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv("train_ctrUa4K.csv")

# %%
dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
dataset.shape
# Out:
# (614, 13)

# %%
dataset = dataset.sample(n=550, random_state = 85)

# %%
dataset.to_csv('GofirjonovMuhammadyusuf_2485.csv')

# %%
data = pd.read_csv('GofirjonovMuhammadyusuf_2485.csv')

# %%
data.head()
# Out:
#    Unnamed: 0   Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0         604  LP002959  Female     Yes          1  Graduate            No
# 1         173  LP001594    Male     Yes          0  Graduate            No
# 2         255  LP001846  Female      No         3+  Graduate            No
# 3          32  LP001097    Male      No          1  Graduate           Yes
# 4         198  LP001671  Female     Yes          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            12000                0.0       496.0             360.0
# 1             5708             5625.0       187.0             360.0
# 2             3083                0.0       255.0             360.0
# 3             4692                0.0       106.0             360.0
# 4             3416             2816.0       113.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0     Semiurban           Y
# 1             1.0     Semiurban           Y
# 2             1.0         Rural           Y
# 3             1.0         Rural           N
# 4             NaN     Semiurban           Y

# %%
data=data.drop('Unnamed: 0', axis = 1)

# %%
data.head()
# Out:
#     Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0  LP002959  Female     Yes          1  Graduate            No
# 1  LP001594    Male     Yes          0  Graduate            No
# 2  LP001846  Female      No         3+  Graduate            No
# 3  LP001097    Male      No          1  Graduate           Yes
# 4  LP001671  Female     Yes          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            12000                0.0       496.0             360.0
# 1             5708             5625.0       187.0             360.0
# 2             3083                0.0       255.0             360.0
# 3             4692                0.0       106.0             360.0
# 4             3416             2816.0       113.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0     Semiurban           Y
# 1             1.0     Semiurban           Y
# 2             1.0         Rural           Y
# 3             1.0         Rural           N
# 4             NaN     Semiurban           Y

# %% [markdown]
# # Q1. Use and explain the following DataFrame functions/properties on your data

# %%
print(data.describe())
print(data.size)
print(data.ndim)
print(data.shape)
(550, 13)
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       550.000000         550.000000  532.000000        538.000000
# mean       5259.378182        1602.614400  145.652256        343.137546
# std        5945.840283        2926.094513   83.188152         63.217985
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2877.500000           0.000000  100.000000        360.000000
# 50%        3768.500000        1211.500000  128.000000        360.000000
# 75%        5741.000000        2269.750000  168.500000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      510.000000
# mean         0.837255
# std          0.369495
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# 7150
# 2
# (550, 13)
# (550, 13)

# %% [markdown]
# # Q2. Is there any difference between dimensions of the original dataset and the new dataset? If yes, what is the difference?

# %%
dataset.shape
(614, 13)
dataset = dataset.sample(n=550, random_state=48)
data.shape
(550, 13)
# Out:
# (550, 13)

# %% [markdown]
# # Q3. What are the possible values 'Education' can take? Write code to display all the possible values of 'Education'.

# %%
# Display all possible values of 'Education'
print(data['Education'].unique())
['Graduate' 'Not Graduate']
# Out:
# ['Graduate' 'Not Graduate']
# ['GraduateNot Graduate']

# %%
columns = data.columns
columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data.head()
# Out:
#     Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0  LP002959  Female     Yes          1  Graduate            No
# 1  LP001594    Male     Yes          0  Graduate            No
# 2  LP001846  Female      No         3+  Graduate            No
# 3  LP001097    Male      No          1  Graduate           Yes
# 4  LP001671  Female     Yes          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            12000                0.0       496.0             360.0
# 1             5708             5625.0       187.0             360.0
# 2             3083                0.0       255.0             360.0
# 3             4692                0.0       106.0             360.0
# 4             3416             2816.0       113.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0     Semiurban           Y
# 1             1.0     Semiurban           Y
# 2             1.0         Rural           Y
# 3             1.0         Rural           N
# 4             NaN     Semiurban           Y

# %%
data['ApplicantIncome'].hist(bins=50)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# Histogram
plt.hist(data['ApplicantIncome'], bins=50, color='skyblue', edgecolor='black')
plt.xlabel('Applicant Income')
plt.ylabel('Frequency')
plt.title('Histogram of Applicant Income')
plt.show()

# Boxplot
plt.boxplot(data['ApplicantIncome'])
plt.ylabel('Applicant Income')
plt.title('Boxplot of Applicant Income')
plt.show()

# %%
data['Credit_History'].value_counts()
# Out:
# Credit_History
# 1.0    427
# 0.0     83
# Name: count, dtype: int64

# %%
credit_history = data['Credit_History'].value_counts(ascending=True)
loan_probability = data.pivot_table(values='Loan_Status', index=['Credit_History'],
aggfunc=lambda x: x.map({'Y':1,'N':0}).mean())
print('Frequency Table for Credit History:')
print(credit_history)
print('\nProbability of getting loan for each Credit History class:')
print(loan_probability)
# Out:
# Frequency Table for Credit History:
# Credit_History
# 0.0     83
# 1.0    427
# Name: count, dtype: int64
#
# Probability of getting loan for each Credit History class:
#                 Loan_Status
# Credit_History
# 0.0                0.084337
# 1.0                0.798595

# %%
data['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    378
# N    172
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (550, 13)

# %%
data.head()
# Out:
#     Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0  LP002959  Female     Yes          1  Graduate            No
# 1  LP001594    Male     Yes          0  Graduate            No
# 2  LP001846  Female      No         3+  Graduate            No
# 3  LP001097    Male      No          1  Graduate           Yes
# 4  LP001671  Female     Yes          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            12000                0.0       496.0             360.0
# 1             5708             5625.0       187.0             360.0
# 2             3083                0.0       255.0             360.0
# 3             4692                0.0       106.0             360.0
# 4             3416             2816.0       113.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0     Semiurban           Y
# 1             1.0     Semiurban           Y
# 2             1.0         Rural           Y
# 3             1.0         Rural           N
# 4             NaN     Semiurban           Y

# %%
fig = plt.figure(figsize=(8,4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('Credit_History')
ax1.set_ylabel('Count of Applicants')
ax1.set_title("Applicants by Credit_History")
credit_history.plot(kind='bar')
plt.show()
ax2 = fig.add_subplot(122)
ax2.set_xlabel('Credit_History')
ax2.set_ylabel('Probability of getting loan')
ax2.set_title("Probability of getting loan by credit history")
loan_probability.plot(kind = 'bar')
plt.show()

# %%
data['Gender'].value_counts()
# Out:
# Gender
# Male      442
# Female     96
# Name: count, dtype: int64

# %%
data.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Loan_ID               0
# Gender               12
# Married               3
# Dependents           14
# Education             0
# Self_Employed        26
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           18
# Loan_Amount_Term     12
# Credit_History       40
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.head()
# Out:
#     Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0  LP002959  Female     Yes          1  Graduate            No
# 1  LP001594    Male     Yes          0  Graduate            No
# 2  LP001846  Female      No         3+  Graduate            No
# 3  LP001097    Male      No          1  Graduate           Yes
# 4  LP001671  Female     Yes          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            12000                0.0       496.0             360.0
# 1             5708             5625.0       187.0             360.0
# 2             3083                0.0       255.0             360.0
# 3             4692                0.0       106.0             360.0
# 4             3416             2816.0       113.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0     Semiurban           Y
# 1             1.0     Semiurban           Y
# 2             1.0         Rural           Y
# 3             1.0         Rural           N
# 4             NaN     Semiurban           Y

# %%
data['LoanAmount'].fillna(data['LoanAmount'].mean(), inplace = True)
# Out:
# /tmp/ipython-input-2713367277.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['LoanAmount'].fillna(data['LoanAmount'].mean(), inplace = True)

# %%
data.head()
# Out:
#     Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0  LP002959  Female     Yes          1  Graduate            No
# 1  LP001594    Male     Yes          0  Graduate            No
# 2  LP001846  Female      No         3+  Graduate            No
# 3  LP001097    Male      No          1  Graduate           Yes
# 4  LP001671  Female     Yes          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            12000                0.0       496.0             360.0
# 1             5708             5625.0       187.0             360.0
# 2             3083                0.0       255.0             360.0
# 3             4692                0.0       106.0             360.0
# 4             3416             2816.0       113.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0     Semiurban           Y
# 1             1.0     Semiurban           Y
# 2             1.0         Rural           Y
# 3             1.0         Rural           N
# 4             NaN     Semiurban           Y

# %%
data.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Loan_ID               0
# Gender               12
# Married               3
# Dependents           14
# Education             0
# Self_Employed        26
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     12
# Credit_History       40
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.shape
# Out:
# (550, 13)

# %%
data.to_csv('new_train.csv')

# %%
data.boxplot(column='LoanAmount', by = ['Education','Self_Employed'],
grid=False, rot = 45, fontsize = 10)
# Out:
# <Axes: title={'center': 'LoanAmount'}, xlabel='[Education, Self_Employed]'>

# %%
data['Self_Employed'].value_counts()
# Out:
# Self_Employed
# No     459
# Yes     65
# Name: count, dtype: int64

# %%
data['Self_Employed'].fillna('No', inplace=True)
# Out:
# /tmp/ipython-input-12615102.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Self_Employed'].fillna('No', inplace=True)

# %%
data['Self_Employed'].value_counts()
# Out:
# Self_Employed
# No     485
# Yes     65
# Name: count, dtype: int64

# %%
data.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Loan_ID               0
# Gender               12
# Married               3
# Dependents           14
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     12
# Credit_History       40
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       550.000000         550.000000  550.000000        538.000000
# mean       5259.378182        1602.614400  145.652256        343.137546
# std        5945.840283        2926.094513   81.813047         63.217985
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3768.500000        1211.500000  129.500000        360.000000
# 75%        5741.000000        2269.750000  165.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      510.000000
# mean         0.837255
# std          0.369495
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
plt.hist(data['LoanAmount'], 20, facecolor='b')
plt.xlabel('Loan Amount')
plt.ylabel('Count')
plt.title('Histogram for loan amount')
plt.grid(True)
plt.show()

# %%
data.boxplot(column='LoanAmount')
# Out:
# <Axes: >

# %%
data['LoanAmount_log'] = np.log(data['LoanAmount'])
#data['LoanAmount_log'].hist(bins = 20)

# %%
plt.hist(data['LoanAmount_log'], 20, facecolor='b')
plt.xlabel('Loan Amount')
plt.ylabel('Count')
plt.title('Histogram for loan amount')
plt.grid(True)
plt.show()

# %%
data.boxplot(column='LoanAmount_log')
# Out:
# <Axes: >

# %%
data.head()
# Out:
#     Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0  LP002959  Female     Yes          1  Graduate            No
# 1  LP001594    Male     Yes          0  Graduate            No
# 2  LP001846  Female      No         3+  Graduate            No
# 3  LP001097    Male      No          1  Graduate           Yes
# 4  LP001671  Female     Yes          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            12000                0.0       496.0             360.0
# 1             5708             5625.0       187.0             360.0
# 2             3083                0.0       255.0             360.0
# 3             4692                0.0       106.0             360.0
# 4             3416             2816.0       113.0             360.0
#
#    Credit_History Property_Area Loan_Status  LoanAmount_log
# 0             1.0     Semiurban           Y        6.206576
# 1             1.0     Semiurban           Y        5.231109
# 2             1.0         Rural           Y        5.541264
# 3             1.0         Rural           N        4.663439
# 4             NaN     Semiurban           Y        4.727388

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       550.000000         550.000000  550.000000        538.000000
# mean       5259.378182        1602.614400  145.652256        343.137546
# std        5945.840283        2926.094513   81.813047         63.217985
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3768.500000        1211.500000  129.500000        360.000000
# 75%        5741.000000        2269.750000  165.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History  LoanAmount_log
# count      510.000000      550.000000
# mean         0.837255        4.858569
# std          0.369495        0.497700
# min          0.000000        2.197225
# 25%          1.000000        4.607658
# 50%          1.000000        4.863673
# 75%          1.000000        5.110477
# max          1.000000        6.551080

# %%
data = data.drop(['LoanAmount'], axis=1)

# %%
# Fill missing values with mode
data['Gender'].fillna(data['Gender'].mode()[0], inplace=True)
data['Married'].fillna(data['Married'].mode()[0], inplace=True)
data['Dependents'].fillna(data['Dependents'].mode()[0], inplace=True)
data['Self_Employed'].fillna(data['Self_Employed'].mode()[0], inplace=True)
data['Loan_Amount_Term'].fillna(data['Loan_Amount_Term'].mode()[0], inplace=True)
data['Credit_History'].fillna(data['Credit_History'].mode()[0], inplace=True)

# Convert categorical variables into numeric
from sklearn.preprocessing import LabelEncoder

categorical_cols = ['Gender', 'Married', 'Dependents', 'Education',
                    'Self_Employed', 'Property_Area', 'Loan_Status']

le = LabelEncoder()
for col in categorical_cols:
    data[col] = le.fit_transform(data[col])

# Check again
print(data.isnull().sum())   # should show 0
print(data.head())           # all categorical columns are numeric now
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# LoanAmount_log       0
# dtype: int64
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP002959       0        1           1          0              0
# 1  LP001594       1        1           0          0              0
# 2  LP001846       0        0           3          0              0
# 3  LP001097       1        0           1          0              1
# 4  LP001671       0        1           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0            12000                0.0             360.0             1.0
# 1             5708             5625.0             360.0             1.0
# 2             3083                0.0             360.0             1.0
# 3             4692                0.0             360.0             1.0
# 4             3416             2816.0             360.0             1.0
#
#    Property_Area  Loan_Status  LoanAmount_log
# 0              1            1        6.206576
# 1              1            1        5.231109
# 2              0            1        5.541264
# 3              0            0        4.663439
# 4              1            1        4.727388
# /tmp/ipython-input-1053789019.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Gender'].fillna(data['Gender'].mode()[0], inplace=True)
# /tmp/ipython-input-1053789019.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Married'].fillna(data['Married'].mode()[0], inplace=True)
# /tmp/ipython-input-1053789019.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Dependents'].fillna(data['Dependents'].mode()[0], inplace=True)
# /tmp/ipython-input-1053789019.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Self_Employed'].fillna(data['Self_Employed'].mode()[0], inplace=True)
# /tmp/ipython-input-1053789019.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Loan_Amount_Term'].fillna(data['Loan_Amount_Term'].mode()[0], inplace=True)
# /tmp/ipython-input-1053789019.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Credit_History'].fillna(data['Credit_History'].mode()[0], inplace=True)

# %%
data['Gender'].fillna(data['Gender'].mode()[0], inplace = True)
#0:gets the mode of each column, 1: for each row
data['Married'].fillna(data['Married'].mode()[0], inplace = True)
data['Dependents'].fillna(data['Dependents'].mode()[0], inplace = True)
data['Loan_Amount_Term'].fillna(data['Loan_Amount_Term'].mode()[0], inplace = True)
data['Credit_History'].fillna(data['Credit_History'].mode()[0], inplace = True)
# Out:
# /tmp/ipython-input-883106805.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Gender'].fillna(data['Gender'].mode()[0], inplace = True)
# /tmp/ipython-input-883106805.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Married'].fillna(data['Married'].mode()[0], inplace = True)
# /tmp/ipython-input-883106805.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Dependents'].fillna(data['Dependents'].mode()[0], inplace = True)
# /tmp/ipython-input-883106805.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Loan_Amount_Term'].fillna(data['Loan_Amount_Term'].mode()[0], inplace = True)
# /tmp/ipython-input-883106805.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Credit_History'].fillna(data['Credit_History'].mode()[0], inplace = True)

# %%
data.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# LoanAmount_log       0
# dtype: int64

# %%
data.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP002959       0        1           1          0              0
# 1  LP001594       1        1           0          0              0
# 2  LP001846       0        0           3          0              0
# 3  LP001097       1        0           1          0              1
# 4  LP001671       0        1           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0            12000                0.0             360.0             1.0
# 1             5708             5625.0             360.0             1.0
# 2             3083                0.0             360.0             1.0
# 3             4692                0.0             360.0             1.0
# 4             3416             2816.0             360.0             1.0
#
#    Property_Area  Loan_Status  LoanAmount_log
# 0              1            1        6.206576
# 1              1            1        5.231109
# 2              0            1        5.541264
# 3              0            0        4.663439
# 4              1            1        4.727388

# %%
data.shape
# Out:
# (550, 13)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
columns = list(data)
print(columns)
# Out:
# ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status', 'LoanAmount_log']

# %%
data.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP002959       0        1           1          0              0
# 1  LP001594       1        1           0          0              0
# 2  LP001846       0        0           3          0              0
# 3  LP001097       1        0           1          0              1
# 4  LP001671       0        1           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0            12000                0.0             360.0             1.0
# 1             5708             5625.0             360.0             1.0
# 2             3083                0.0             360.0             1.0
# 3             4692                0.0             360.0             1.0
# 4             3416             2816.0             360.0             1.0
#
#    Property_Area  Loan_Status  LoanAmount_log
# 0              1            1        6.206576
# 1              1            1        5.231109
# 2              0            1        5.541264
# 3              0            0        4.663439
# 4              1            1        4.727388

# %%
#columns = list(data.select_dtypes(exclude=['float64','int64']))

# %%
c_columns = ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']

# %%
data.dtypes
# Out:
# Loan_ID               object
# Gender                 int64
# Married                int64
# Dependents             int64
# Education              int64
# Self_Employed          int64
# ApplicantIncome        int64
# CoapplicantIncome    float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area          int64
# Loan_Status            int64
# LoanAmount_log       float64
# dtype: object

# %%
le = LabelEncoder()
for i in c_columns:
#print(i)
  data[i] = le.fit_transform(data[i])

# %%
data.head(25)
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0   LP002959       0        1           1          0              0
# 1   LP001594       1        1           0          0              0
# 2   LP001846       0        0           3          0              0
# 3   LP001097       1        0           1          0              1
# 4   LP001671       0        1           0          0              0
# 5   LP002804       0        1           0          0              0
# 6   LP002364       1        1           0          0              0
# 7   LP001864       1        1           3          1              0
# 8   LP001922       1        1           0          0              0
# 9   LP001888       0        0           0          0              0
# 10  LP002036       1        1           0          0              0
# 11  LP002716       1        0           0          1              0
# 12  LP002347       1        1           0          0              0
# 13  LP001610       1        1           3          0              0
# 14  LP001431       0        0           0          0              0
# 15  LP002792       1        1           1          0              0
# 16  LP002401       1        1           0          0              0
# 17  LP002562       1        1           1          1              0
# 18  LP002585       1        1           0          0              0
# 19  LP002137       1        1           0          0              0
# 20  LP001497       1        1           2          0              0
# 21  LP001487       1        0           0          0              0
# 22  LP001367       1        1           1          0              0
# 23  LP001784       1        1           1          0              0
# 24  LP001213       1        1           1          0              0
#
#     ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0             12000                0.0             360.0             1.0
# 1              5708             5625.0             360.0             1.0
# 2              3083                0.0             360.0             1.0
# 3              4692                0.0             360.0             1.0
# 4              3416             2816.0             360.0             1.0
# 5              4180             2306.0             360.0             1.0
# 6             14880                0.0             360.0             1.0
# 7              4931                0.0             360.0             1.0
# 8             20667                0.0             360.0             1.0
# 9              3237                0.0             360.0             1.0
# 10             2058             2134.0             360.0             1.0
# 11             6783                0.0             360.0             1.0
# 12             3246             1417.0             360.0             1.0
# 13             5516            11300.0             360.0             0.0
# 14             2137             8980.0             360.0             0.0
# 15             5468             1032.0             360.0             1.0
# 16             2213             1125.0             360.0             1.0
# 17             5333             1131.0             360.0             1.0
# 18             3597             2157.0             360.0             0.0
# 19             6333             4583.0             360.0             1.0
# 20             5042             2083.0             360.0             1.0
# 21             4895                0.0             360.0             1.0
# 22             3052             1030.0             360.0             1.0
# 23             5500             1260.0             360.0             1.0
# 24             4945                0.0             360.0             0.0
#
#     Property_Area  Loan_Status  LoanAmount_log
# 0               1            1        6.206576
# 1               1            1        5.231109
# 2               0            1        5.541264
# 3               0            0        4.663439
# 4               1            1        4.727388
# 5               1            1        5.204007
# 6               1            1        4.564348
# 7               1            0        4.852030
# 8               0            0        4.981222
# 9               2            1        3.401197
# 10              2            1        4.477337
# 11              1            1        4.867534
# 12              1            1        4.927254
# 13              1            0        6.204558
# 14              1            1        4.919981
# 15              1            1        3.258097
# 16              2            1        4.981222
# 17              2            1        5.225747
# 18              0            0        4.779123
# 19              1            1        5.556828
# 20              0            0        5.220356
# 21              1            1        4.624973
# 22              2            1        4.605170
# 23              0            1        5.135798
# 24              0            0        4.981222

# %%
#from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize

# %%
original_data = data.copy()
original_data.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP002959       0        1           1          0              0
# 1  LP001594       1        1           0          0              0
# 2  LP001846       0        0           3          0              0
# 3  LP001097       1        0           1          0              1
# 4  LP001671       0        1           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0            12000                0.0             360.0             1.0
# 1             5708             5625.0             360.0             1.0
# 2             3083                0.0             360.0             1.0
# 3             4692                0.0             360.0             1.0
# 4             3416             2816.0             360.0             1.0
#
#    Property_Area  Loan_Status  LoanAmount_log
# 0              1            1        6.206576
# 1              1            1        5.231109
# 2              0            1        5.541264
# 3              0            0        4.663439
# 4              1            1        4.727388

# %%
original_data[0:5]
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP002959       0        1           1          0              0
# 1  LP001594       1        1           0          0              0
# 2  LP001846       0        0           3          0              0
# 3  LP001097       1        0           1          0              1
# 4  LP001671       0        1           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0            12000                0.0             360.0             1.0
# 1             5708             5625.0             360.0             1.0
# 2             3083                0.0             360.0             1.0
# 3             4692                0.0             360.0             1.0
# 4             3416             2816.0             360.0             1.0
#
#    Property_Area  Loan_Status  LoanAmount_log
# 0              1            1        6.206576
# 1              1            1        5.231109
# 2              0            1        5.541264
# 3              0            0        4.663439
# 4              1            1        4.727388

# %%
data.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP002959       0        1           1          0              0
# 1  LP001594       1        1           0          0              0
# 2  LP001846       0        0           3          0              0
# 3  LP001097       1        0           1          0              1
# 4  LP001671       0        1           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0            12000                0.0             360.0             1.0
# 1             5708             5625.0             360.0             1.0
# 2             3083                0.0             360.0             1.0
# 3             4692                0.0             360.0             1.0
# 4             3416             2816.0             360.0             1.0
#
#    Property_Area  Loan_Status  LoanAmount_log
# 0              1            1        6.206576
# 1              1            1        5.231109
# 2              0            1        5.541264
# 3              0            0        4.663439
# 4              1            1        4.727388

# %%
data[0:5]
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP002959       0        1           1          0              0
# 1  LP001594       1        1           0          0              0
# 2  LP001846       0        0           3          0              0
# 3  LP001097       1        0           1          0              1
# 4  LP001671       0        1           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# 0            12000                0.0             360.0             1.0
# 1             5708             5625.0             360.0             1.0
# 2             3083                0.0             360.0             1.0
# 3             4692                0.0             360.0             1.0
# 4             3416             2816.0             360.0             1.0
#
#    Property_Area  Loan_Status  LoanAmount_log
# 0              1            1        6.206576
# 1              1            1        5.231109
# 2              0            1        5.541264
# 3              0            0        4.663439
# 4              1            1        4.727388

# %%
data_for_norm = data.drop(['Loan_ID','Loan_Status'], axis=1)

# %%
normalized_data = normalize( data_for_norm )

# %%
print(normalized_data[0:5])
# Out:
# [[0.00000000e+00 8.32958463e-05 8.32958463e-05 0.00000000e+00
#   0.00000000e+00 9.99550156e-01 0.00000000e+00 2.99865047e-02
#   8.32958463e-05 8.32958463e-05 5.16981995e-04]
#  [1.24658126e-04 1.24658126e-04 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 7.11548584e-01 7.01201959e-01 4.48769254e-02
#   1.24658126e-04 1.24658126e-04 6.52100197e-04]
#  [0.00000000e+00 0.00000000e+00 9.66509205e-04 0.00000000e+00
#   0.00000000e+00 9.93249293e-01 0.00000000e+00 1.15981105e-01
#   3.22169735e-04 0.00000000e+00 1.78522741e-03]
#  [2.12504025e-04 0.00000000e+00 2.12504025e-04 0.00000000e+00
#   2.12504025e-04 9.97068887e-01 0.00000000e+00 7.65014491e-02
#   2.12504025e-04 0.00000000e+00 9.90999580e-04]
#  [0.00000000e+00 2.25139945e-04 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 7.69078052e-01 6.33994085e-01 8.10503802e-02
#   2.25139945e-04 2.25139945e-04 1.06432383e-03]]

# %%
normalized_data.shape
# Out:
# (550, 11)

# %%
data.shape
# Out:
# (550, 13)

# %%
normalized_data = pd.DataFrame(normalized_data, columns=data_for_norm.columns)

# %%
normalized_data.head()
# Out:
#      Gender   Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0  0.000000  0.000083    0.000083        0.0       0.000000         0.999550
# 1  0.000125  0.000125    0.000000        0.0       0.000000         0.711549
# 2  0.000000  0.000000    0.000967        0.0       0.000000         0.993249
# 3  0.000213  0.000000    0.000213        0.0       0.000213         0.997069
# 4  0.000000  0.000225    0.000000        0.0       0.000000         0.769078
#
#    CoapplicantIncome  Loan_Amount_Term  Credit_History  Property_Area  \
# 0           0.000000          0.029987        0.000083       0.000083
# 1           0.701202          0.044877        0.000125       0.000125
# 2           0.000000          0.115981        0.000322       0.000000
# 3           0.000000          0.076501        0.000213       0.000000
# 4           0.633994          0.081050        0.000225       0.000225
#
#    LoanAmount_log
# 0        0.000517
# 1        0.000652
# 2        0.001785
# 3        0.000991
# 4        0.001064

# %%
normalized_data['Loan_ID'] = data['Loan_ID']

# %%
normalized_data.head()
# Out:
#      Gender   Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0  0.000000  0.000083    0.000083        0.0       0.000000         0.999550
# 1  0.000125  0.000125    0.000000        0.0       0.000000         0.711549
# 2  0.000000  0.000000    0.000967        0.0       0.000000         0.993249
# 3  0.000213  0.000000    0.000213        0.0       0.000213         0.997069
# 4  0.000000  0.000225    0.000000        0.0       0.000000         0.769078
#
#    CoapplicantIncome  Loan_Amount_Term  Credit_History  Property_Area  \
# 0           0.000000          0.029987        0.000083       0.000083
# 1           0.701202          0.044877        0.000125       0.000125
# 2           0.000000          0.115981        0.000322       0.000000
# 3           0.000000          0.076501        0.000213       0.000000
# 4           0.633994          0.081050        0.000225       0.000225
#
#    LoanAmount_log   Loan_ID
# 0        0.000517  LP002959
# 1        0.000652  LP001594
# 2        0.001785  LP001846
# 3        0.000991  LP001097
# 4        0.001064  LP001671

# %%
normalized_data['Loan_Status'] = data['Loan_Status']

# %%
normalized_data.head(10)
# Out:
#      Gender   Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0  0.000000  0.000083    0.000083   0.000000       0.000000         0.999550
# 1  0.000125  0.000125    0.000000   0.000000       0.000000         0.711549
# 2  0.000000  0.000000    0.000967   0.000000       0.000000         0.993249
# 3  0.000213  0.000000    0.000213   0.000000       0.000213         0.997069
# 4  0.000000  0.000225    0.000000   0.000000       0.000000         0.769078
# 5  0.000000  0.000209    0.000000   0.000000       0.000000         0.873116
# 6  0.000067  0.000067    0.000000   0.000000       0.000000         0.999707
# 7  0.000202  0.000202    0.000607   0.000202       0.000000         0.997345
# 8  0.000048  0.000048    0.000000   0.000000       0.000000         0.999848
# 9  0.000000  0.000000    0.000000   0.000000       0.000000         0.993872
#
#    CoapplicantIncome  Loan_Amount_Term  Credit_History  Property_Area  \
# 0           0.000000          0.029987        0.000083       0.000083
# 1           0.701202          0.044877        0.000125       0.000125
# 2           0.000000          0.115981        0.000322       0.000000
# 3           0.000000          0.076501        0.000213       0.000000
# 4           0.633994          0.081050        0.000225       0.000225
# 5           0.481676          0.075197        0.000209       0.000209
# 6           0.000000          0.024186        0.000067       0.000067
# 7           0.000000          0.072814        0.000202       0.000202
# 8           0.000000          0.017416        0.000048       0.000000
# 9           0.000000          0.110533        0.000307       0.000614
#
#    LoanAmount_log   Loan_ID  Loan_Status
# 0        0.000517  LP002959            1
# 1        0.000652  LP001594            1
# 2        0.001785  LP001846            1
# 3        0.000991  LP001097            0
# 4        0.001064  LP001671            1
# 5        0.001087  LP002804            1
# 6        0.000307  LP002364            1
# 7        0.000981  LP001864            0
# 8        0.000241  LP001922            0
# 9        0.001044  LP001888            1

# %%
normalized_data.describe()
# Out:
#            Gender     Married  Dependents   Education  Self_Employed  \
# count  550.000000  550.000000  550.000000  550.000000     550.000000
# mean     0.000185    0.000146    0.000164    0.000058       0.000022
# std      0.000124    0.000131    0.000252    0.000119       0.000068
# min      0.000000    0.000000    0.000000    0.000000       0.000000
# 25%      0.000099    0.000000    0.000000    0.000000       0.000000
# 50%      0.000193    0.000153    0.000000    0.000000       0.000000
# 75%      0.000272    0.000250    0.000286    0.000000       0.000000
# max      0.000673    0.000589    0.001609    0.000673       0.000455
#
#        ApplicantIncome  CoapplicantIncome  Loan_Amount_Term  Credit_History  \
# count       550.000000         550.000000        550.000000      550.000000
# mean          0.876547           0.306527          0.079415        0.000194
# std           0.172774           0.316687          0.038669        0.000123
# min           0.009983           0.000000          0.002842        0.000000
# 25%           0.796426           0.000000          0.050412        0.000109
# 50%           0.967178           0.244610          0.078304        0.000204
# 75%           0.997069           0.593314          0.104405        0.000277
# max           0.999996           0.999941          0.242218        0.000673
#
#        Property_Area  LoanAmount_log  Loan_Status
# count     550.000000      550.000000   550.000000
# mean        0.000244        0.001085     0.687273
# std         0.000238        0.000422     0.464026
# min         0.000000        0.000073     0.000000
# 25%         0.000000        0.000813     0.000000
# 50%         0.000215        0.001085     1.000000
# 75%         0.000364        0.001345     1.000000
# max         0.001346        0.002671     1.000000

# %%
# normalized_data['LoanAmount'].hist(bins=100)

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.tree import export_graphviz
from sklearn.metrics import ConfusionMatrixDisplay
import pydotplus

# %%
columns = list(normalized_data.columns)
columns
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'ApplicantIncome',
#  'CoapplicantIncome',
#  'Loan_Amount_Term',
#  'Credit_History',
#  'Property_Area',
#  'LoanAmount_log',
#  'Loan_ID',
#  'Loan_Status']

# %%
normalized_data.head()
# Out:
#      Gender   Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0  0.000000  0.000083    0.000083        0.0       0.000000         0.999550
# 1  0.000125  0.000125    0.000000        0.0       0.000000         0.711549
# 2  0.000000  0.000000    0.000967        0.0       0.000000         0.993249
# 3  0.000213  0.000000    0.000213        0.0       0.000213         0.997069
# 4  0.000000  0.000225    0.000000        0.0       0.000000         0.769078
#
#    CoapplicantIncome  Loan_Amount_Term  Credit_History  Property_Area  \
# 0           0.000000          0.029987        0.000083       0.000083
# 1           0.701202          0.044877        0.000125       0.000125
# 2           0.000000          0.115981        0.000322       0.000000
# 3           0.000000          0.076501        0.000213       0.000000
# 4           0.633994          0.081050        0.000225       0.000225
#
#    LoanAmount_log   Loan_ID  Loan_Status
# 0        0.000517  LP002959            1
# 1        0.000652  LP001594            1
# 2        0.001785  LP001846            1
# 3        0.000991  LP001097            0
# 4        0.001064  LP001671            1

# %%
features = normalized_data.drop(['Loan_ID','Loan_Status'], axis = 1)
classes = pd.DataFrame(normalized_data['Loan_Status'])

# %%
print('Features:')
print(features.head())
print('Classes:')
print(classes.head())
# Out:
# Features:
#      Gender   Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0  0.000000  0.000083    0.000083        0.0       0.000000         0.999550
# 1  0.000125  0.000125    0.000000        0.0       0.000000         0.711549
# 2  0.000000  0.000000    0.000967        0.0       0.000000         0.993249
# 3  0.000213  0.000000    0.000213        0.0       0.000213         0.997069
# 4  0.000000  0.000225    0.000000        0.0       0.000000         0.769078
#
#    CoapplicantIncome  Loan_Amount_Term  Credit_History  Property_Area  \
# 0           0.000000          0.029987        0.000083       0.000083
# 1           0.701202          0.044877        0.000125       0.000125
# 2           0.000000          0.115981        0.000322       0.000000
# 3           0.000000          0.076501        0.000213       0.000000
# 4           0.633994          0.081050        0.000225       0.000225
#
#    LoanAmount_log
# 0        0.000517
# 1        0.000652
# 2        0.001785
# 3        0.000991
# 4        0.001064
# Classes:
#    Loan_Status
# 0            1
# 1            1
# 2            1
# 3            0
# 4            1

# %%
normalized_data.head(10)
# Out:
#      Gender   Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0  0.000000  0.000083    0.000083   0.000000       0.000000         0.999550
# 1  0.000125  0.000125    0.000000   0.000000       0.000000         0.711549
# 2  0.000000  0.000000    0.000967   0.000000       0.000000         0.993249
# 3  0.000213  0.000000    0.000213   0.000000       0.000213         0.997069
# 4  0.000000  0.000225    0.000000   0.000000       0.000000         0.769078
# 5  0.000000  0.000209    0.000000   0.000000       0.000000         0.873116
# 6  0.000067  0.000067    0.000000   0.000000       0.000000         0.999707
# 7  0.000202  0.000202    0.000607   0.000202       0.000000         0.997345
# 8  0.000048  0.000048    0.000000   0.000000       0.000000         0.999848
# 9  0.000000  0.000000    0.000000   0.000000       0.000000         0.993872
#
#    CoapplicantIncome  Loan_Amount_Term  Credit_History  Property_Area  \
# 0           0.000000          0.029987        0.000083       0.000083
# 1           0.701202          0.044877        0.000125       0.000125
# 2           0.000000          0.115981        0.000322       0.000000
# 3           0.000000          0.076501        0.000213       0.000000
# 4           0.633994          0.081050        0.000225       0.000225
# 5           0.481676          0.075197        0.000209       0.000209
# 6           0.000000          0.024186        0.000067       0.000067
# 7           0.000000          0.072814        0.000202       0.000202
# 8           0.000000          0.017416        0.000048       0.000000
# 9           0.000000          0.110533        0.000307       0.000614
#
#    LoanAmount_log   Loan_ID  Loan_Status
# 0        0.000517  LP002959            1
# 1        0.000652  LP001594            1
# 2        0.001785  LP001846            1
# 3        0.000991  LP001097            0
# 4        0.001064  LP001671            1
# 5        0.001087  LP002804            1
# 6        0.000307  LP002364            1
# 7        0.000981  LP001864            0
# 8        0.000241  LP001922            0
# 9        0.001044  LP001888            1

# %%
normalized_data.shape
# Out:
# (550, 13)

# %%
normalized_data.shape
# Out:
# (550, 13)

# %%
#https://machinelearningmastery.com/calculate-feature-importance-with-python/

# %%
from matplotlib import pyplot

# %%
x_train, x_test, y_train, y_test = train_test_split(features, classes, test_size= .33,
random_state = 1)
print(x_train.shape, x_test.shape)
# Out:
# (368, 11) (182, 11)

# %%
decisionTree = DecisionTreeClassifier(criterion='entropy')
print(decisionTree)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dtc_model = decisionTree.fit(x_train, y_train)

# %%
# feature importance
importance = dtc_model.feature_importances_

for i,v in enumerate(importance):
   print('Feature: %0d, Score: %.5f' % (i,v))

# Barchat for feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.13443
# Feature: 1, Score: 0.08738
# Feature: 2, Score: 0.08562
# Feature: 3, Score: 0.00000
# Feature: 4, Score: 0.01209
# Feature: 5, Score: 0.01854
# Feature: 6, Score: 0.04330
# Feature: 7, Score: 0.12053
# Feature: 8, Score: 0.29960
# Feature: 9, Score: 0.09777
# Feature: 10, Score: 0.10074

# %%
prediction = dtc_model.predict(x_test) #prediction stores the predicted targets/classes

# %%
y_true = le.inverse_transform(y_test["Loan_Status"])
y_pred = le.inverse_transform(prediction)

# %%
cm = confusion_matrix(y_true, y_pred)
labels = ['Y', 'N']
ConfusionMatrixDisplay(cm, display_labels=labels).plot()

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.60      0.55        53
#            1       0.82      0.75      0.79       129
#
#     accuracy                           0.71       182
#    macro avg       0.66      0.68      0.67       182
# weighted avg       0.73      0.71      0.72       182

# %%
graphviz_path = 'C:/Program Files/Graphviz/bin/'

# %%
import os
os.environ["PATH"] += os.pathsep + graphviz_path

# %%
from graphviz import Source
from sklearn import tree
graph = Source( tree.export_graphviz(dtc_model, out_file=None, feature_names=features.columns))

# %%
from cairosvg import svg2png
from IPython.display import Image

svg2png(bytestring=graph.pipe(format='svg'),write_to='output.png')
Image("output.png")

# %% [markdown]
# <a href="https://colab.research.google.com/github/GMuhammadyusuf/GMuhammadyusuf/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv("train_ctrUa4K.csv")

# %%
dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
dataset.shape
# Out:
# (614, 13)

# %%
dataset = dataset.sample(n=550, random_state=85)

# %%
dataset.to_csv('VinitaNahar_2448.cvs')

# %%
data = pd.read_csv('VinitaNahar_2448.cvs')

# %%
data.head()
# Out:
#    Unnamed: 0   Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0         604  LP002959  Female     Yes          1  Graduate            No
# 1         173  LP001594    Male     Yes          0  Graduate            No
# 2         255  LP001846  Female      No         3+  Graduate            No
# 3          32  LP001097    Male      No          1  Graduate           Yes
# 4         198  LP001671  Female     Yes          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            12000                0.0       496.0             360.0
# 1             5708             5625.0       187.0             360.0
# 2             3083                0.0       255.0             360.0
# 3             4692                0.0       106.0             360.0
# 4             3416             2816.0       113.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0     Semiurban           Y
# ...

# %%
data=data.drop('Unnamed: 0', axis = 1)

# %%
data.head()
# Out:
#     Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0  LP002959  Female     Yes          1  Graduate            No
# 1  LP001594    Male     Yes          0  Graduate            No
# 2  LP001846  Female      No         3+  Graduate            No
# 3  LP001097    Male      No          1  Graduate           Yes
# 4  LP001671  Female     Yes          0  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0            12000                0.0       496.0             360.0
# 1             5708             5625.0       187.0             360.0
# 2             3083                0.0       255.0             360.0
# 3             4692                0.0       106.0             360.0
# 4             3416             2816.0       113.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0     Semiurban           Y
# 1             1.0     Semiurban           Y
# ...

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       550.000000         550.000000  532.000000        538.000000
# mean       5259.378182        1602.614400  145.652256        343.137546
# std        5945.840283        2926.094513   83.188152         63.217985
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2877.500000           0.000000  100.000000        360.000000
# 50%        3768.500000        1211.500000  128.000000        360.000000
# 75%        5741.000000        2269.750000  168.500000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      510.000000
# mean         0.837255
# std          0.369495
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
data.size
# Out:
# 7150

# %%
data.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (550, 13)

# %% [markdown]
# Q1
# When I applied the pandas functions to my dataset, I learned the following
#
# Using describe(), I saw the statistical summary of the numeric columns, including the mean, standard deviation, minimum, maximum, and quartiles. This gave me a quick overview of how the data is distributed.
#
# With size, I found that my DataFrame contains 7150 total elements.
#
# By checking ndim, I confirmed that the DataFrame is two dimensional, consisting of rows and columns.
#
# Finally, shape showed me that the dataset has 550 rows and 13 columns.
#
# Through these functions, I was able to understand both the structure and the distribution of my data more clearly.

# %% [markdown]
# data.describe()
# This function gives summary statistics for numeric columns:
#
# ApplicantIncome: Mean = 5259.38, Std = 5945.84, Min = 150, Max = 81000
#
# CoapplicantIncome: Mean = 1602.61, Std = 2926.09, Min = 0, Max = 41667
#
# LoanAmount: Mean = 145.65, Std = 83.19, Min = 9, Max = 700
#
# Loan_Amount_Term: Most common term is 360 months
#
# Credit_History: Mostly 1.0 (good credit), with some 0.0
#
#
#
# data.size
# 7150 → Total number of elements in the DataFrame. Calculated as: 550 rows × 13 columns = 7150
#
#
#
# data.ndim
# 2 → The DataFrame is two-dimensional (rows and columns).
#
#
#
# data.shape
# (550, 13) → The DataFrame has 550 rows and 13 columns.

# %% [markdown]
# Q2
# Yes, there is a difference between the dimensions of the original dataset and the new dataset.
#
# The original dataset likely had more rows and columns before cleaning or preprocessing.
#
# The new dataset has dimensions (550, 13) — meaning 550 rows and 13 columns.
#
# This change usually happens due to:
#
# Removing rows with missing values
#
# Dropping irrelevant or duplicate columns
#
# Filtering specific records
#
# So, the difference reflects how the data was cleaned or transformed for analysis.
